# %%
colores = ["rojo","azul","verde","Morado"]
personas = ["Nairo","Valentina","Rodolfo","Mitsue"]

# %%
for i,color in enumerate(colores):
    print(i)
    print(color)
    print("hola")
    for persona in personas:
        print(persona)
print("adios")
# Out:
# 0
# rojo
# hola
# Nairo
# Valentina
# Rodolfo
# Mitsue
# 1
# azul
# hola
# Nairo
# Valentina
# Rodolfo
# Mitsue
# 2
# verde
# hola
# Nairo
# Valentina
# Rodolfo
# Mitsue
# 3
# Morado
# hola
# Nairo
# Valentina
# Rodolfo
# Mitsue
# adios

# %%
for color in colores:
    if color == "azul":
        print(color)
print("termine")
# Out:
# azul
# termine

# %%
contador = 0
while contador < 10:
    # contador = contador + 1
    contador += 1
    print(contador)
    if contador != 7:
        print(f"No es el siete {contador}")
# Out:
# 1
# No es el siete 1
# 2
# No es el siete 2
# 3
# No es el siete 3
# 4
# No es el siete 4
# 5
# No es el siete 5
# 6
# No es el siete 6
# 7
# 8
# No es el siete 8
# 9
# No es el siete 9
# 10
# No es el siete 10

# %%
3 > 5
# Out:
# False

# %%
3 >= 3
# Out:
# True

# %%
while True:
    print("2")
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# ...
